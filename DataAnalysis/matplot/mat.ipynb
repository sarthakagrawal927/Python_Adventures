# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,])

# %%
x = [1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y);

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
## Recommended method
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [11,12,13,14]

fig,ax = plt.subplots(figsize = (10,10))

ax.plot(x,y)

ax.set(title="Simple", xlabel="x-axis", ylabel="y-axis")

fig.savefig("simple-plot.png")

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots()
ax.plot(x,x**2);

# %%
#Scatter plot
fig,ax = plt.subplots()
ax.scatter(x,x**9);

# %%
#make a plot from dictionary
nuts = {"small":4, "medium":5,"large":9}
fig,ax = plt.subplots()
ax.bar(nuts.keys(),height = nuts.values())
ax.set(title="cost price",xlabel= " type", ylabel= "prices");

# %%
fig,ax = plt.subplots()
ax.barh(list(nuts.keys()), list(nuts.values()));

# %%
# histograms
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %%
fig, ( (ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2, ncols =2, figsize= (10,5));

ax1.plot(x,x/2);
ax2.bar(x,x**2);
ax4.scatter(x,2*x);
ax3.hist(x);

# %%
fig, ax = plt.subplots(nrows = 2, ncols =2, figsize= (10,5));

ax[0,0].plot(x,x/2);
ax[0,1].bar(x,x**2);
ax[1,0].scatter(x,2*x);
ax[1,1].hist(x);

# %% [markdown]
# ### Plotting from pandas Dataframes

# %%
car_sales = pd.read_csv("Z:\Coding\PythonMagic\DataAnalysis\matplot\car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range("9/9/2020", periods= 1000))

ts = ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("9/9/2020", periods= len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-09-09
# 1   Honda    Red          87899      4   5000 2020-09-10
# 2  Toyota   Blue          32549      3   7000 2020-09-11
# 3     BMW  Black          11179      5  22000 2020-09-12
# 4  Nissan  White         213095      4   3500 2020-09-13
# 5  Toyota  Green          99213      4   4500 2020-09-14
# 6   Honda   Blue          45698      4   7500 2020-09-15
# 7   Honda   Blue          54738      4   7000 2020-09-16
# 8  Toyota  White          60000      4   6250 2020-09-17
# 9  Nissan  White          31600      4   9700 2020-09-18

# %%
car_sales["Total_Sale"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total_Sale
# 0  Toyota  White         150043      4   4000 2020-09-09        4000
# 1   Honda    Red          87899      4   5000 2020-09-10        9000
# 2  Toyota   Blue          32549      3   7000 2020-09-11       16000
# 3     BMW  Black          11179      5  22000 2020-09-12       38000
# 4  Nissan  White         213095      4   3500 2020-09-13       41500
# 5  Toyota  Green          99213      4   4500 2020-09-14       46000
# 6   Honda   Blue          45698      4   7500 2020-09-15       53500
# 7   Honda   Blue          54738      4   7000 2020-09-16       60500
# 8  Toyota  White          60000      4   6250 2020-09-17       66750
# 9  Nissan  White          31600      4   9700 2020-09-18       76450

# %%
car_sales.plot(x="Sale Date", y ="Total_Sale" );

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y = "Price", kind="scatter")

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x, columns = ['a','b','b','d'])
df
# df.plot(kind="bar");
# Out:
#           a         b         b         d
# 0  0.712353  0.037318  0.572407  0.066831
# 1  0.824196  0.517255  0.668632  0.484040
# 2  0.279816  0.847755  0.872919  0.413316
# 3  0.700824  0.853414  0.285442  0.755863
# 4  0.988087  0.476904  0.398720  0.680847
# 5  0.517578  0.828150  0.427317  0.641064
# 6  0.139830  0.526123  0.972857  0.324637
# 7  0.417476  0.792027  0.549191  0.197761
# 8  0.057485  0.003473  0.557186  0.314176
# 9  0.563169  0.549852  0.232435  0.576229

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total_Sale
# 0  Toyota  White         150043      4   4000 2020-09-09        4000
# 1   Honda    Red          87899      4   5000 2020-09-10        9000
# 2  Toyota   Blue          32549      3   7000 2020-09-11       16000
# 3     BMW  Black          11179      5  22000 2020-09-12       38000
# 4  Nissan  White         213095      4   3500 2020-09-13       41500
# 5  Toyota  Green          99213      4   4500 2020-09-14       46000
# 6   Honda   Blue          45698      4   7500 2020-09-15       53500
# 7   Honda   Blue          54738      4   7000 2020-09-16       60500
# 8  Toyota  White          60000      4   6250 2020-09-17       66750
# 9  Nissan  White          31600      4   9700 2020-09-18       76450

# %%
car_sales.plot(x= "Make", y= "Odometer (KM)", kind = "bar");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=15);

# %%
heart = pd.read_csv("Z:\Coding\PythonMagic\DataAnalysis\matplot\heart-disease.csv")
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart["age"].plot.hist(bins = 100);

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.plot.hist(figsize = (10,30) ,subplots  = True);

# %%
over50 = heart[heart["age"] > 50]
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#pyplot
over50.plot(kind="scatter", x='age', y= 'chol', c= 'target');

# %%
#object oriented method
fig, ax = plt.subplots(figsize = (10,6))
over50.plot(kind='scatter',x='age',y='chol',c='target',ax = ax);
ax.set_xlim([45,80]);

# %%
fig ,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over50["age"], y = over50["chol"], c = over50["target"]);

# add title and axis
ax.set(title="Heart didease and cholestrol levels", xlabel="Age", ylabel= "Cholesterol");

# add legends
ax.legend(*scatter.legend_elements(), title = "Target");

# adding an horizontal line
ax.axhline(over50["chol"].mean(), linestyle='--');

# %%
fig, (ax0,ax1) = plt.subplots(nrows=2,ncols=1, figsize=(10,10), sharex=True)

scatter = ax0.scatter(x=over50["age"], y=over50["chol"], c= over50["target"]);
ax0.set(title="Cholestrol", ylabel="cholesterol");
ax0.axhline(over50["chol"].mean(), linestyle = '--');
ax0.legend(*scatter.legend_elements(),title = "target");

scatter2 = ax1.scatter(x=over50["age"], y = over50['thalach'], c = over50['target']);
ax1.set(title="THalach", xlabel="Age", ylabel="thalach");
ax1.axhline(over50["thalach"].mean(), linestyle = '--');
ax1.legend(*scatter.legend_elements(),title = "target");

#adding title to the figure
fig.suptitle("Hear disease analysis", fontweight = "bold");

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot();

# %%
df
# Out:
#           a         b         b         d
# 0  0.712353  0.037318  0.572407  0.066831
# 1  0.824196  0.517255  0.668632  0.484040
# 2  0.279816  0.847755  0.872919  0.413316
# 3  0.700824  0.853414  0.285442  0.755863
# 4  0.988087  0.476904  0.398720  0.680847
# 5  0.517578  0.828150  0.427317  0.641064
# 6  0.139830  0.526123  0.972857  0.324637
# 7  0.417476  0.792027  0.549191  0.197761
# 8  0.057485  0.003473  0.557186  0.314176
# 9  0.563169  0.549852  0.232435  0.576229

# %%
fig, (ax0,ax1) = plt.subplots(nrows=2,ncols=1, figsize=(10,10), sharex=True)

scatter = ax0.scatter(x=over50["age"], y=over50["chol"], c= over50["target"], cmap="winter");
ax0.set(title="Cholestrol", ylabel="cholesterol");
ax0.axhline(over50["chol"].mean(), linestyle = '--');
ax0.legend(*scatter.legend_elements(),title = "target");

ax0.set_xlim([50,80])
ax1.set_ylim([60,200])

scatter2 = ax1.scatter(x=over50["age"], y = over50['thalach'], c = over50['target'], cmap="summer");
ax1.set(title="THalach", xlabel="Age", ylabel="thalach");
ax1.axhline(over50["thalach"].mean(), linestyle = '--');
ax1.legend(*scatter.legend_elements(),title = "target");

#adding title to the figure
fig.suptitle("Hear disease analysis", fontweight = "bold");
